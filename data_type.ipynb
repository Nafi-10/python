# %%
type(-12 + 100)
# Out:
# int

# %%
type(1.12 + 10.45)
# Out:
# float

# %%
type(12 + 3j)
# Out:
# complex

# %%
#Boolean(T/F)
type(False)
type(True)
type(1>5)
# Out:
# bool

# %%
#Strings

'Single Quote'
# Out:
# 'Double Quote'

# %%
"Double Quote"
# Out:
# 'Double Quote'

# %%
multi_line = """
My name is Kazi Jawadul Islam,
I live in Bangladesh,
Right now i study in Daffodil International University.
"""
print(multi_line)
# Out:
# My name is Kazi Jawadul Islam,
# I live in Bangladesh,
# Right now i study in Daffodil International University.

# %%
#Indexing
a='Hello World'
print(a[:5]
# Out:
# Hello

# %%
b='Hello World'
print(b[4])
# Out:
# o

# %%
#List
[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
['Chocolate','Vanilla','Strawberry']
# Out:
# ['Chocolate', 'Vanilla', 'Strawberry']

# %%
['Vanilla','Chocolate',3,['Orange','Mango'],True]
# Out:
# ['Vanilla', 'Chocolate', 3, ['Orange', 'Mango'], True]

# %%
ice_cream=['Chocolate','Vanilla','Strawberry']
ice_cream.append('Cold Choco') #add items to the list
ice_cream
# Out:
# ['Chocolate', 'Vanilla', 'Strawberry', 'Cold Choco']

# %%
ice_cream[0]='Butter Scotch'
ice_cream
# Out:
# ['Butter Scotch', 'Vanilla', 'Strawberry', 'Cold Choco']

# %%
nested_list=['Vanilla','Chocolate',3,['Orange','Mango'],True]
nested_list[3][0]
# Out:
# 'Orange'

# %%
#tuple (can't change its value)

tuple_scoops = (1,2,3,1,2,4)
tuple_scoops
# Out:
# (1, 2, 3, 1, 2, 4)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
#sets

daily_pins={1,2,3,4,5}
print(daily_pins)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(daily_pins)
# Out:
# set

# %%
daily_pins_log={1,2,3,4,5,65,43,1,2,3,4,5,8,7,5,6,7,8}
print(daily_pins_log)
# Out:
# {1, 2, 3, 4, 5, 65, 7, 8, 6, 43}

# %%
wife_daily_pins_log={1,2,3,4,5,55,65,87}
print(wife_daily_pins_log)
# Out:
# {1, 2, 3, 4, 5, 65, 55, 87}

# %%
print(daily_pins_log|wife_daily_pins_log)
# Out:
# {1, 2, 3, 4, 5, 65, 7, 8, 6, 43, 87, 55}

# %%
print(daily_pins_log & wife_daily_pins_log)
# Out:
# {1, 2, 3, 4, 5, 65}

# %%
print(daily_pins_log-wife_daily_pins_log)
# Out:
# {8, 43, 6, 7}

# %%
print(wife_daily_pins_log - daily_pins_log)
# Out:
# {87, 55}

# %%
#Dictionaries

# %%
dict_cream={'name': 'Jawad','Weekly Intake':10,'Favorite Ice Cream': ['MCC','Chocolate']}
dict_cream
# Out:
# {'name': 'Jawad',
#  'Weekly Intake': 10,
#  'Favorite Ice Cream': ['MCC', 'Chocolate']}

# %%
type(dict_cream)
# Out:
# dict

# %%
dict_cream.values()
# Out:
# dict_values(['Jawad', 10, ['MCC', 'Chocolate']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'Weekly Intake', 'Favorite Ice Cream'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'Jawad'), ('Weekly Intake', 10), ('Favorite Ice Cream', ['MCC', 'Chocolate'])])

# %%
dict_cream['name']
# Out:
# 'Jawad'

# %%
dict_cream['name']='Nafi'

print(dict_cream)
# Out:
# {'name': 'Nafi', 'Weekly Intake': 10, 'Favorite Ice Cream': ['MCC', 'Chocolate']}

# %%
dict_cream.update({'name': 'Nafi', 'Weekly Intake': 10, 'Weight': 300})
print(dict_cream)
# Out:
# {'name': 'Nafi', 'Weekly Intake': 10, 'Favorite Ice Cream': ['MCC', 'Chocolate'], 'Weight': 300}

# %%
#update the value of Key
dict_cream.update({'name': 'Nafi', 'Weekly Intake': 15, 'Weight': 300})
print(dict_cream)
# Out:
# {'name': 'Nafi', 'Weekly Intake': 15, 'Favorite Ice Cream': ['MCC', 'Chocolate'], 'Weight': 300}

# %%
del dict_cream['Weight']
print(dict_cream)
# Out:
# {'name': 'Nafi', 'Weekly Intake': 15, 'Favorite Ice Cream': ['MCC', 'Chocolate']}
