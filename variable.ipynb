# %%
#Variable in Python

x = 22
print(x)
type(x)
# Out:
# 22
# int

# %%
y="My Name is Jawad"
print(y)
type(y)
# Out:
# My Name is Jawad
# str

# %%
x,y,z='Kazi','Jawadul','Islam'

print(x)
print(y)
print(z)
# Out:
# Kazi
# Jawadul
# Islam

# %%
x=y=z='Jawadul Islam'

print(x)
print(y)
print(z)
# Out:
# Jawadul Islam
# Jawadul Islam
# Jawadul Islam

# %%
name = ['Kazi','Jawadul','Islam']
x,y,z=name
print(x)
print(y)
print(z)
# Out:
# Kazi
# Jawadul
# Islam

# %%
#Concatenate
a = 'My Name is ' + 'Jawad'
print(a)

b=2+3
print('The value of b is',b)
# Out:
# My Name is Jawad
# The value of b is 5

# %%
a='My name'
b=' is'
c=' Jawadul Islam'

print(a+b+c)
# Out:
# My name is Jawadul Islam
