# %%
num_int=7
type(num_int)
# Out:
# int

# %%
num_str="7"
type(num_str)
# Out:
# str

# %%
#adding both integer and string

num_str_convt=int(num_str) #converting string into integer

num_sum=num_int + num_str_convt
print(num_sum)
type(num_str_convt)
# Out:
# 14
# int

# %%
#converting list into a tuple

list_type=[2,3,4,5,6,7,8,9]
type(list_type)
# Out:
# list

# %%
tuple(list_type)
type(tuple(list_type))
# Out:
# tuple

# %%
#Converting a list into a set
list_type=[1,2,3,4,2,3,1,5,6,7,8,2,4,5,]
type(list_type)
# Out:
# list

# %%
set(list_type) # When we convert a list into set the data will change if there any repeat in value
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#Converting dictionary into a list

dist_type={'Name':'Jawad','Age':22,'Nationality':'Bangladeshi'}

print(dist_type)
type(dist_type)
# Out:
# {'Name': 'Jawad', 'Age': 22, 'Nationality': 'Bangladeshi'}
# dict

# %%
dist_type.items()
# Out:
# dict_items([('Name', 'Jawad'), ('Age', 22), ('Nationality', 'Bangladeshi')])

# %%
dist_type.values()
# Out:
# dict_values(['Jawad', 22, 'Bangladeshi'])

# %%
dist_type.keys()
# Out:
# dict_keys(['Name', 'Age', 'Nationality'])

# %%
list(dist_type.values())
# Out:
# ['Jawad', 22, 'Bangladeshi']

# %%
type(list(dist_type.values()))
# Out:
# list

# %%
list(dist_type.keys())
# Out:
# ['Name', 'Age', 'Nationality']

# %%
type(list(dist_type.keys()))
# Out:
# list

# %%
#Long String
long_str=('I love to do analysis')

# %%
list(long_str)
# Out:
# ['I',
#  ' ',
#  'l',
#  'o',
#  'v',
#  'e',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'd',
#  'o',
#  ' ',
#  'a',
#  'n',
#  'a',
#  'l',
#  'y',
#  's',
#  'i',
#  's']

# %%
set(long_str)
# Out:
# {' ', 'I', 'a', 'd', 'e', 'i', 'l', 'n', 'o', 's', 't', 'v', 'y'}
