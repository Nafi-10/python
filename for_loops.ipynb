# %%
integers=[1,2,3,4,5]
for number in integers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
integers=[1,2,3,4,5]
for number in integers:
    print('Jawad')
# Out:
# Jawad
# Jawad
# Jawad
# Jawad
# Jawad

# %%
integers=[1,2,3,4,5]
for jelly in integers:
    print(jelly + jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
integers=[1,2,3,4,5]
for jelly in integers:
    print(jelly + 1)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
ice_cream_dict={'name': 'Jawad','Weekly Intake':10,'Favorite Ice Cream': ['MCC','Chocolate']}
for cream in ice_cream_dict.values():
    print(cream)
# Out:
# Jawad
# 10
# ['MCC', 'Chocolate']

# %%
ice_cream_dict={'name': 'Jawad','Weekly Intake':10,'Favorite Ice Cream': ['MCC','Chocolate']}
for key,value in ice_cream_dict.items():
    print(key,'->',value)
# Out:
# name -> Jawad
# Weekly Intake -> 10
# Favorite Ice Cream -> ['MCC', 'Chocolate']

# %%
#Nested For Loops

# %%
flavours = ['Vanilla','Chocolate','Mango']
toopings = ['Choco Chips','Oreos','Kitkat']

for one in flavours:
    for two in toopings:
        print(one,'topped with',two)
# Out:
# Vanilla topped with Choco Chips
# Vanilla topped with Oreos
# Vanilla topped with Kitkat
# Chocolate topped with Choco Chips
# Chocolate topped with Oreos
# Chocolate topped with Kitkat
# Mango topped with Choco Chips
# Mango topped with Oreos
# Mango topped with Kitkat
